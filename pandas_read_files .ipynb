# %%
import pandas
dtxt = pandas.read_csv("G:\python_files\data_files\Emp.csv", header = None, names = ["Eid","Ename","Erole"])

# %%
dtxt
# Out:
#         Ename     Erole
# Eid
# Salary    Dep  Quantity
# 5000    Fruit        91
# 6000    Fruit        92
# 10000   Fruit        93
# 3000    Fruit        94
# 6000    Fruit        95
# 10000   Fruit        96
# 9000    Fruit        97
# 5000    Fruit        98
# 3000      Veg        99

# %%
dtxt.sort_values(by = "Eid")
# Out:
#         Ename     Erole
# Eid
# 10000   Fruit        93
# 10000   Fruit        96
# 3000    Fruit        94
# 3000      Veg        99
# 5000    Fruit        91
# 5000    Fruit        98
# 6000    Fruit        92
# 6000    Fruit        95
# 9000    Fruit        97
# Salary    Dep  Quantity

# %%
dtxt.Erole.sum()
# Out:
# 'Quantity919293949596979899'

# %%
url='https://en.wikipedia.org/wiki/Sundar_Pichai'

# %%
print(type(url))
# Out:
# <class 'str'>

# %%
d =pandas.read_html(url)[0]

# %%
print(d)
# Out:
#      Sundar Pichai                                    Sundar Pichai.1
# 0              NaN                                                NaN
# 1             Born  Pichai Sundararajan (age 47)Madurai, Tamil Nad...
# 2        Education  Indian Institute of Technology Kharagpur (BTec...
# 3            Title                         CEO of Google and Alphabet
# 4  Board member of                      Alphabet Inc.[1]Magic Leap[2]
# 5        Spouse(s)                                      Anjali Pichai
# 6         Children                                                  2

# %%
dtxt = pandas.read_excel("G:\python_files\data_files\dep.xlsx", header = None, names = ["Ename","Edep","Eid","Eloc"], sheet_name =2)

# %%
print(dtxt)
# Out:
#     Ename   Edep  Eid       Eloc
# 0   Ename   Edep  Eid       Eloc
# 1   Apple  Fruit    1    Kashmir
# 2  Banana  Fruit    2     Nanded
# 3  Orange  Fruit    3  Chitthore

# %%
dtxt = pandas.read_csv("G:\python_files\data_files\Emp.csv")

# %%
dtxt
# Out:
#        Name  Id location         Dob  Salary    Dep  Quantity
# 0     Apple   1   Guntur  01-01-2000    5000  Fruit        91
# 1    Banana   2      Hyd  02-01-2000    6000  Fruit        92
# 2    Orange   3   ongole  30-09-2000   10000  Fruit        93
# 3     Guava   4    Delhi  01-01-2000    3000  Fruit        94
# 4     Grape   5  Kurnool  02-01-2000    6000  Fruit        95
# 5   Avocado   6    Vizag  30-09-2000   10000  Fruit        96
# 6      Kivi   7  Chennai  01-01-2000    9000  Fruit        97
# 7   Kismiss   8  Kashmir  02-01-2000    5000  Fruit        98
# 8  Cucumber   9   Mumbai  30-09-2000    3000    Veg        99

# %%
dtxt.loc[[1,2]]
# Out:
#      Name  Id location         Dob  Salary    Dep
# 1  Banana   2      Hyd  02-01-2000    6000  Fruit
# 2  Orange   3   ongole  30-09-2000   10000  Fruit

# %%
dtxt.iloc[3:5]
# Out:
#     Name  Id location         Dob  Salary    Dep
# 3  Guava   4    Delhi  01-01-2000    3000  Fruit
# 4  Grape   5  Kurnool  02-01-2000    6000  Fruit

# %%
dtxt.set_index("Salary", inplace = True)

# %%
dtxt
# Out:
#             Name  Id location         Dob    Dep
# Salary
# 5000       Apple   1   Guntur  01-01-2000  Fruit
# 6000      Banana   2      Hyd  02-01-2000  Fruit
# 10000     Orange   3   ongole  30-09-2000  Fruit
# 3000       Guava   4    Delhi  01-01-2000  Fruit
# 6000       Grape   5  Kurnool  02-01-2000  Fruit
# 10000    Avocado   6    Vizag  30-09-2000  Fruit
# 9000        Kivi   7  Chennai  01-01-2000  Fruit
# 5000     Kismiss   8  Kashmir  02-01-2000  Fruit
# 3000    Cucumber   9   Mumbai  30-09-2000    Veg

# %%
dtxt.loc[5000,"location"]
# Out:
# Salary
# 5000     Guntur
# 5000    Kashmir
# Name: location, dtype: object

# %%
dtxt.loc[9000]
# Out:
# Name              Kivi
# Id                   7
# location       Chennai
# Dob         01-01-2000
# Dep              Fruit
# Name: 9000, dtype: object

# %%
dtxt = pandas.read_csv("G:\python_files\data_files\Emp.csv")

# %%
dtxt
# Out:
#        Name  Id location         Dob  Salary    Dep  Quantity
# 0     Apple   1   Guntur  01-01-2000    5000  Fruit        91
# 1    Banana   2      Hyd  02-01-2000    6000  Fruit        92
# 2    Orange   3   ongole  30-09-2000   10000  Fruit        93
# 3     Guava   4    Delhi  01-01-2000    3000  Fruit        94
# 4     Grape   5  Kurnool  02-01-2000    6000  Fruit        95
# 5   Avocado   6    Vizag  30-09-2000   10000  Fruit        96
# 6      Kivi   7  Chennai  01-01-2000    9000  Fruit        97
# 7   Kismiss   8  Kashmir  02-01-2000    5000  Fruit        98
# 8  Cucumber   9   Mumbai  30-09-2000    3000    Veg        99

# %%
dtxt[dtxt.loc[:,"Salary"] < 5000]
# Out:
#        Name  Id location         Dob  Salary    Dep  Quantity
# 3     Guava   4    Delhi  01-01-2000    3000  Fruit        94
# 8  Cucumber   9   Mumbai  30-09-2000    3000    Veg        99

# %%
dtxt[(dtxt.loc[:,"Salary"] < 5000)  & (dtxt.loc[:,"Dep"] == "Veg")]
# Out:
#        Name  Id location         Dob  Salary  Dep  Quantity
# 8  Cucumber   9   Mumbai  30-09-2000    3000  Veg        99

# %%
dtxt["Quantity"] = ["1","2","3","9","8","7","6","4","5"]
dtxt
# Out:
#        Name  Id location         Dob  Salary    Dep Quantity
# 0     Apple   1   Guntur  01-01-2000    5000  Fruit        1
# 1    Banana   2      Hyd  02-01-2000    6000  Fruit        2
# 2    Orange   3   ongole  30-09-2000   10000  Fruit        3
# 3     Guava   4    Delhi  01-01-2000    3000  Fruit        9
# 4     Grape   5  Kurnool  02-01-2000    6000  Fruit        8
# 5   Avocado   6    Vizag  30-09-2000   10000  Fruit        7
# 6      Kivi   7  Chennai  01-01-2000    9000  Fruit        6
# 7   Kismiss   8  Kashmir  02-01-2000    5000  Fruit        4
# 8  Cucumber   9   Mumbai  30-09-2000    3000    Veg        5

# %%
dtxt.to_csv("G:\python_files\data_files\Fruits.csv")

# %%
df = pandas.read_csv("G:\python_files\data_files\Fruits.csv")
df
# Out:
#    Unnamed: 0      Name  Id location         Dob  Salary    Dep  Quantity
# 0           0     Apple   1   Guntur  01-01-2000    5000  Fruit         1
# 1           1    Banana   2      Hyd  02-01-2000    6000  Fruit         2
# 2           2    Orange   3   ongole  30-09-2000   10000  Fruit         3
# 3           3     Guava   4    Delhi  01-01-2000    3000  Fruit         9
# 4           4     Grape   5  Kurnool  02-01-2000    6000  Fruit         8
# 5           5   Avocado   6    Vizag  30-09-2000   10000  Fruit         7
# 6           6      Kivi   7  Chennai  01-01-2000    9000  Fruit         6
# 7           7   Kismiss   8  Kashmir  02-01-2000    5000  Fruit         4
# 8           8  Cucumber   9   Mumbai  30-09-2000    3000    Veg         5

# %%
n_df= df.append(dtxt)

# %%
n_df
# Out:
#    Unnamed: 0      Name  Id location         Dob  Salary    Dep Quantity
# 0         0.0     Apple   1   Guntur  01-01-2000    5000  Fruit        1
# 1         1.0    Banana   2      Hyd  02-01-2000    6000  Fruit        2
# 2         2.0    Orange   3   ongole  30-09-2000   10000  Fruit        3
# 3         3.0     Guava   4    Delhi  01-01-2000    3000  Fruit        9
# 4         4.0     Grape   5  Kurnool  02-01-2000    6000  Fruit        8
# 5         5.0   Avocado   6    Vizag  30-09-2000   10000  Fruit        7
# 6         6.0      Kivi   7  Chennai  01-01-2000    9000  Fruit        6
# 7         7.0   Kismiss   8  Kashmir  02-01-2000    5000  Fruit        4
# 8         8.0  Cucumber   9   Mumbai  30-09-2000    3000    Veg        5
# 0         NaN     Apple   1   Guntur  01-01-2000    5000  Fruit        1
# 1         NaN    Banana   2      Hyd  02-01-2000    6000  Fruit        2
# 2         NaN    Orange   3   ongole  30-09-2000   10000  Fruit        3
# ...

# %%
#Adding a column to a data frame
dtxt["Phone"] = ["123","456","789","987","654","321","741","852","963"]
dtxt
# Out:
#        Name  Id location         Dob  Salary    Dep  Quantity Phone
# 0     Apple   1   Guntur  01-01-2000    5000  Fruit        91   123
# 1    Banana   2      Hyd  02-01-2000    6000  Fruit        92   456
# 2    Orange   3   ongole  30-09-2000   10000  Fruit        93   789
# 3     Guava   4    Delhi  01-01-2000    3000  Fruit        94   987
# 4     Grape   5  Kurnool  02-01-2000    6000  Fruit        95   654
# 5   Avocado   6    Vizag  30-09-2000   10000  Fruit        96   321
# 6      Kivi   7  Chennai  01-01-2000    9000  Fruit        97   741
# 7   Kismiss   8  Kashmir  02-01-2000    5000  Fruit        98   852
# 8  Cucumber   9   Mumbai  30-09-2000    3000    Veg        99   963

# %%
#Adding a row to a data frame
dtxt1 = dtxt.append(pandas.Series(["Carrot",10,"Ongole","20-10-2000",2000,"Veg",98,456], index = dtxt.columns), ignore_index = True)

# %%
dtxt1
# Out:
#        Name  Id location         Dob  Salary    Dep  Quantity Phone
# 0     Apple   1   Guntur  01-01-2000    5000  Fruit        91   123
# 1    Banana   2      Hyd  02-01-2000    6000  Fruit        92   456
# 2    Orange   3   ongole  30-09-2000   10000  Fruit        93   789
# 3     Guava   4    Delhi  01-01-2000    3000  Fruit        94   987
# 4     Grape   5  Kurnool  02-01-2000    6000  Fruit        95   654
# 5   Avocado   6    Vizag  30-09-2000   10000  Fruit        96   321
# 6      Kivi   7  Chennai  01-01-2000    9000  Fruit        97   741
# 7   Kismiss   8  Kashmir  02-01-2000    5000  Fruit        98   852
# 8  Cucumber   9   Mumbai  30-09-2000    3000    Veg        99   963
# 9    Carrot  10   Ongole  20-10-2000    2000    Veg        98   456

# %%
  #Updating a column
dtxt1.loc[(dtxt1["location"] == "Hyd") & (dtxt1["Dep"] == "Fruit"), "Salary"] = "6000"

# %%
dtxt1
# Out:
#        Name  Id location         Dob Salary    Dep  Quantity Phone
# 0     Apple   1   Guntur  01-01-2000   5000  Fruit        91   123
# 1    Banana   2      Hyd  02-01-2000   6000  Fruit        92   456
# 2    Orange   3   ongole  30-09-2000  10000  Fruit        93   789
# 3     Guava   4    Delhi  01-01-2000   3000  Fruit        94   987
# 4     Grape   5  Kurnool  02-01-2000   6000  Fruit        95   654
# 5   Avocado   6    Vizag  30-09-2000  10000  Fruit        96   321
# 6      Kivi   7  Chennai  01-01-2000   9000  Fruit        97   741
# 7   Kismiss   8  Kashmir  02-01-2000   5000  Fruit        98   852
# 8  Cucumber   9   Mumbai  30-09-2000   3000    Veg        99   963
# 9    Carrot  10   Ongole  20-10-2000   2000    Veg        98   456

# %%
  #Updating multiple columns
dtxt1.loc[(dtxt1["location"] == "Hyd") & (dtxt1["Dep"] == "Fruit"), ["Salary","Quantity"]] = [600,90]

# %%
dtxt1
# Out:
#        Name  Id location         Dob  Salary    Dep  Quantity Phone
# 0     Apple   1   Guntur  01-01-2000    5000  Fruit        91   123
# 1    Banana   2      Hyd  02-01-2000     600  Fruit        90   456
# 2    Orange   3   ongole  30-09-2000   10000  Fruit        93   789
# 3     Guava   4    Delhi  01-01-2000    3000  Fruit        94   987
# 4     Grape   5  Kurnool  02-01-2000    6000  Fruit        95   654
# 5   Avocado   6    Vizag  30-09-2000   10000  Fruit        96   321
# 6      Kivi   7  Chennai  01-01-2000    9000  Fruit        97   741
# 7   Kismiss   8  Kashmir  02-01-2000    5000  Fruit        98   852
# 8  Cucumber   9   Mumbai  30-09-2000    3000    Veg        99   963
# 9    Carrot  10   Ongole  20-10-2000    2000    Veg        98   456

# %%
dtxt1.loc["Dep"] = "Veg"

# %%
dtxt1
# Out:
#          Name   Id location         Dob Salary    Dep Quantity Phone
# 0       Apple    1   Guntur  01-01-2000   5000  Fruit       91   123
# 1      Banana    2      Hyd  02-01-2000   6000  Fruit       92   456
# 2      Orange    3   ongole  30-09-2000  10000  Fruit       93   789
# 3       Guava    4    Delhi  01-01-2000   3000  Fruit       94   987
# 4       Grape    5  Kurnool  02-01-2000   6000  Fruit       95   654
# 5     Avocado    6    Vizag  30-09-2000  10000  Fruit       96   321
# 6        Kivi    7  Chennai  01-01-2000   9000  Fruit       97   741
# 7     Kismiss    8  Kashmir  02-01-2000   5000  Fruit       98   852
# 8    Cucumber    9   Mumbai  30-09-2000   3000    Veg       99   963
# 9      Carrot   10   Ongole  20-10-2000   2000    Veg       98   456
# Dep       Veg  Veg      Veg         Veg    Veg    Veg      Veg   Veg

# %%
#Sort data
dtxt1.set_index("Salary", inplace = True)
dtxt1
# Out:
#             Name   Id location         Dob    Dep Quantity Phone
# Salary
# 5000       Apple    1   Guntur  01-01-2000  Fruit       91   123
# 6000      Banana    2      Hyd  02-01-2000  Fruit       92   456
# 10000     Orange    3   ongole  30-09-2000  Fruit       93   789
# 3000       Guava    4    Delhi  01-01-2000  Fruit       94   987
# 6000       Grape    5  Kurnool  02-01-2000  Fruit       95   654
# 10000    Avocado    6    Vizag  30-09-2000  Fruit       96   321
# 9000        Kivi    7  Chennai  01-01-2000  Fruit       97   741
# 5000     Kismiss    8  Kashmir  02-01-2000  Fruit       98   852
# 3000    Cucumber    9   Mumbai  30-09-2000    Veg       99   963
# 2000      Carrot   10   Ongole  20-10-2000    Veg       98   456
# Veg          Veg  Veg      Veg         Veg    Veg      Veg   Veg

# %%
#Drop a column
dtxt1.drop("Veg", inplace = True)
dtxt1
# Out:
#             Name  Id location         Dob    Dep Quantity Phone
# Salary
# 5000       Apple   1   Guntur  01-01-2000  Fruit       91   123
# 6000      Banana   2      Hyd  02-01-2000  Fruit       92   456
# 10000     Orange   3   ongole  30-09-2000  Fruit       93   789
# 3000       Guava   4    Delhi  01-01-2000  Fruit       94   987
# 6000       Grape   5  Kurnool  02-01-2000  Fruit       95   654
# 10000    Avocado   6    Vizag  30-09-2000  Fruit       96   321
# 9000        Kivi   7  Chennai  01-01-2000  Fruit       97   741
# 5000     Kismiss   8  Kashmir  02-01-2000  Fruit       98   852
# 3000    Cucumber   9   Mumbai  30-09-2000    Veg       99   963
# 2000      Carrot  10   Ongole  20-10-2000    Veg       98   456

# %%
dtxt1
# Out:
#             Name  Id location         Dob    Dep Quantity Phone
# Salary
# 5000       Apple   1   Guntur  01-01-2000  Fruit       91   123
# 6000      Banana   2      Hyd  02-01-2000  Fruit       92   456
# 10000     Orange   3   ongole  30-09-2000  Fruit       93   789
# 3000       Guava   4    Delhi  01-01-2000  Fruit       94   987
# 6000       Grape   5  Kurnool  02-01-2000  Fruit       95   654
# 10000    Avocado   6    Vizag  30-09-2000  Fruit       96   321
# 9000        Kivi   7  Chennai  01-01-2000  Fruit       97   741
# 5000     Kismiss   8  Kashmir  02-01-2000  Fruit       98   852
# 3000    Cucumber   9   Mumbai  30-09-2000    Veg       99   963
# 2000      Carrot  10   Ongole  20-10-2000    Veg       98   456

# %%
#Drop a column from columns
dtxt1.drop("Phone", "columns")
# Out:
#             Name  Id location         Dob    Dep Quantity
# Salary
# 5000       Apple   1   Guntur  01-01-2000  Fruit       91
# 6000      Banana   2      Hyd  02-01-2000  Fruit       92
# 10000     Orange   3   ongole  30-09-2000  Fruit       93
# 3000       Guava   4    Delhi  01-01-2000  Fruit       94
# 6000       Grape   5  Kurnool  02-01-2000  Fruit       95
# 10000    Avocado   6    Vizag  30-09-2000  Fruit       96
# 9000        Kivi   7  Chennai  01-01-2000  Fruit       97
# 5000     Kismiss   8  Kashmir  02-01-2000  Fruit       98
# 3000    Cucumber   9   Mumbai  30-09-2000    Veg       99
# 2000      Carrot  10   Ongole  20-10-2000    Veg       98

# %%
#Deleting Rows based on index : First 3(0,1,2) indexed rows will be deleted
dtxt1.drop(dtxt1.index[2])
# Out:
#             Name  Id location         Dob    Dep Quantity Phone
# Salary
# 5000       Apple   1   Guntur  01-01-2000  Fruit       91   123
# 6000      Banana   2      Hyd  02-01-2000  Fruit       92   456
# 3000       Guava   4    Delhi  01-01-2000  Fruit       94   987
# 6000       Grape   5  Kurnool  02-01-2000  Fruit       95   654
# 9000        Kivi   7  Chennai  01-01-2000  Fruit       97   741
# 5000     Kismiss   8  Kashmir  02-01-2000  Fruit       98   852
# 3000    Cucumber   9   Mumbai  30-09-2000    Veg       99   963
# 2000      Carrot  10   Ongole  20-10-2000    Veg       98   456

# %%
#Deleting Rows based on index : First 3(0,1,2) indexed rows will be deleted--Excluding
dtxt1.drop(dtxt1.index[0:2])
# Out:
#             Name  Id location         Dob    Dep Quantity Phone
# Salary
# 10000     Orange   3   ongole  30-09-2000  Fruit       93   789
# 3000       Guava   4    Delhi  01-01-2000  Fruit       94   987
# 10000    Avocado   6    Vizag  30-09-2000  Fruit       96   321
# 9000        Kivi   7  Chennai  01-01-2000  Fruit       97   741
# 3000    Cucumber   9   Mumbai  30-09-2000    Veg       99   963
# 2000      Carrot  10   Ongole  20-10-2000    Veg       98   456

# %%
#Deleting columns based on index Dob column will be deleted
dtxt1.drop(dtxt1.columns[3],1)
# Out:
#             Name  Id location    Dep Quantity Phone
# Salary
# 5000       Apple   1   Guntur  Fruit       91   123
# 6000      Banana   2      Hyd  Fruit       92   456
# 10000     Orange   3   ongole  Fruit       93   789
# 3000       Guava   4    Delhi  Fruit       94   987
# 6000       Grape   5  Kurnool  Fruit       95   654
# 10000    Avocado   6    Vizag  Fruit       96   321
# 9000        Kivi   7  Chennai  Fruit       97   741
# 5000     Kismiss   8  Kashmir  Fruit       98   852
# 3000    Cucumber   9   Mumbai    Veg       99   963
# 2000      Carrot  10   Ongole    Veg       98   456

# %%
#Deleting columns based on index (Quantity,Phone) column will be deleted
dtxt1.drop(dtxt1.columns[5:],1)
# Out:
#             Name  Id location         Dob    Dep
# Salary
# 5000       Apple   1   Guntur  01-01-2000  Fruit
# 6000      Banana   2      Hyd  02-01-2000  Fruit
# 10000     Orange   3   ongole  30-09-2000  Fruit
# 3000       Guava   4    Delhi  01-01-2000  Fruit
# 6000       Grape   5  Kurnool  02-01-2000  Fruit
# 10000    Avocado   6    Vizag  30-09-2000  Fruit
# 9000        Kivi   7  Chennai  01-01-2000  Fruit
# 5000     Kismiss   8  Kashmir  02-01-2000  Fruit
# 3000    Cucumber   9   Mumbai  30-09-2000    Veg
# 2000      Carrot  10   Ongole  20-10-2000    Veg
